# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
data = pd.read_csv ('data/Automobile_data.csv')
data
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                 99  alfa-romero       gas        std
# 1            3                 99  alfa-romero       gas        std
# 2            1                 99  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1                 95        volvo       gas        std
# 200         -1                 95        volvo       gas      turbo
# 201         -1                 95        volvo       gas        std
# 202         -1                 95        volvo    diesel      turbo
# 203         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
data['make'].replace({'alfa-romero':50, 'audi':51, 'volvo':52, 'subaru':53, 'toyota':54, 'saab':55,
                       'mercury':56, 'volkswagen':57, 'renault':58,  'porsche':59, 
                       'plymouth':60, 'peugot':61, 'nissan':62, 'mitsubishi':63,
                        'mercedes-benz':64, 'mazda':65, 'jaguar':66, 'isuzu':67,
                        'honda':68, 'dodge':69, 'chevrolet':70, 'bmw':71}, inplace=True)
data.groupby("make").size()
# Out:
# make
# 50     3
# 51     7
# 52    11
# 53    13
# 54    31
# 55     6
# 56     1
# 57    12
# 58     2
# 59     5
# 60     7
# 61    11
# 62    18
# 63    13
# 64     8
# 65    17
# 66     3
# 67     4
# 68    13
# 69     9
# 70     2
# 71     8
# dtype: int64

# %%
data.groupby("drive-wheels").size()
data['drive-wheels'].replace({'rwd':45, '4wd':46, 'fwd':47}, inplace=True)

# %%
data.groupby("body-style").size()
data['body-style'].replace({'sedan':35, 'hatchback':36, 'convertible':37, 'wagon':38, 'hardtop':39}, inplace=True)

# %%
data.groupby("num-of-doors").size()
data['num-of-doors'].replace({'two':31, 'four':30}, inplace=True)

# %%
data.groupby("num-of-cylinders").size()
data['num-of-cylinders'].replace({'two':1, 'four':2, 'five':3, 'six':4, 'eight':5, 'twelve':6}, inplace=True)

# %%
data.groupby("fuel-type").size()
data['fuel-type'].replace({'gas':25, 'diesel':24}, inplace=True)

# %%
data.groupby("aspiration").size()
data['aspiration'].replace({'std':20, 'turbo':21}, inplace=True)

# %%
data.groupby("fuel-system").size()
data['fuel-system'].replace({'mpfi':0, 'idi':1, '2bbl':2, '1bbl':3, '4bbl':4, 'spdi':5, 'mfi':6, 'spfi':7}, inplace=True)

# %%
data.groupby("engine-type").size()
data['engine-type'].replace({'dohc':0, 'dohcv':1, 'l':2, 'ohc':3, 'ohcf':4, 'ohcv':5, 'rotor':6}, inplace=True)

# %%
data.groupby("make").size()
data['make'].replace({'audi':9, 'volvo':8, 'alfa-romero':7}, inplace=True)

# %%
data.groupby("engine-location").size()
data['engine-location'].replace({'front':11, 'rear':12}, inplace=True)

# %%
data
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 99    50         25          20            31
# 1            3                 99    50         25          20            31
# 2            1                 99    50         25          20            31
# 3            2                164    51         25          20            30
# 4            2                164    51         25          20            30
# ..         ...                ...   ...        ...         ...           ...
# 199         -1                 95    52         25          20            30
# 200         -1                 95    52         25          21            30
# 201         -1                 95    52         25          20            30
# 202         -1                 95    52         24          21            30
# 203         -1                 95    52         25          21            30
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
x =LabelEncoder()
data ['body-style'] = x.fit_transform(data['body-style'])
data.to_csv('toyota.csv')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 99    50         25          20            31
# 1            3                 99    50         25          20            31
# 2            1                 99    50         25          20            31
# 3            2                164    51         25          20            30
# 4            2                164    51         25          20            30
# ..         ...                ...   ...        ...         ...           ...
# 199         -1                 95    52         25          20            30
# 200         -1                 95    52         25          21            30
# 201         -1                 95    52         25          20            30
# 202         -1                 95    52         24          21            30
# 203         -1                 95    52         25          21            30
#
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
array=data.values
x=array[:,0:25 ]
y=array[:, 25]
y
# Out:
# array([13495., 16500., 16500., 13950., 17450., 15250., 17710., 18920.,
#        23875., 30000., 16430., 16925., 20970., 21105., 24565., 30760.,
#        41315., 36880.,  6295.,  6575.,  5572.,  6377.,  7957.,  6229.,
#         6692.,  7609.,  8558.,  8921., 12964.,  6479.,  6855.,  5399.,
#         6529.,  7129.,  7295.,  7295.,  7895.,  9095.,  8845., 10295.,
#        12945., 10345.,  6785., 30000., 30000., 11048., 32250., 35550.,
#        36000.,  5195.,  6095.,  6795.,  6695.,  7395., 10945., 11845.,
#        13645., 15645.,  8845.,  8495., 10595., 10245., 10795., 11245.,
#        18280., 18344., 25552., 28248., 28176., 31600., 34184., 35056.,
#        40960., 45400., 16503.,  5389.,  6189.,  6669.,  7689.,  9959.,
#         8499., 12629., 14869., 14489.,  6989.,  8189.,  9279.,  9279.,
#         5499.,  7099.,  6649.,  6849.,  7349.,  7299.,  7799.,  7499.,
#         7999.,  8249.,  8949.,  9549., 13499., 14399., 13499., 17199.,
# ...

# %%
import sklearn
from sklearn import model_selection
#Step 2: Split all the 2105 rows into 2 parts
#Parts 1 wil have training data 70% data
#Part 2 will have testing data 30% data


x_train ,x_test,y_train,y_test=model_selection.train_test_split(x,y,
                                                        test_size=0.3,
                                                        random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC # Support Vector Machine ,SVM

#Switch the models
model=LinearRegression()
#Fit only 70% of data
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(x_test)
print('Answers',predictions)
print('Expected',y_test)
#The model predicts the 30% of data we compare results with Y_test
from sklearn.metrics  import r2_score
print(r2_score(predictions,y_test))
# Out:
# Answers [26546.77927404 15904.66750789 16429.46085709  3813.10164049
#  22560.40032948 11892.25847907 13823.63613432  7263.69950475
#  23256.53763761  6575.801491   25581.64599324  6246.32329665
#  10250.87202097  4090.9987648   8240.90971235  9689.56159784
#  10884.97832864  8867.83922052  8213.91870676  9006.44402054
#  19655.15683549  2858.25930947  8080.21402268  6789.74552806
#  35519.72528173 26749.22367347 10518.402125    9882.21090935
#  12162.21675488 16844.44667751 13899.4565335  17794.70353417
#  30065.15255255 20347.80712019  7053.24501781 19384.08656356
#  10196.56492398  6027.74968965 13341.96407211 10707.48680514
#  13658.7423163  19757.67489893  6279.57271238 11503.57632627
#   9884.06000307  6058.27886311 16429.46085709 10027.3783212
#  12953.60451003  9298.36985605  7375.34800343 13338.15168651
#   6101.43207547 12870.51003826  4210.45235702  4620.78133883
#  16002.90045266 10510.44811617 14376.29980865 10755.92297422
#  31760.23894163  8906.43639409]
# ...

# %%
#Step 5:Lets make a recipe
# symboling	normalized-losses	make	fuel-type	aspiration	num-of-doors	body-style	drive-wheels	engine-location	wheel-base	length	width	height	curb-weight	engine-type	num-of-cylinders	engine-size	fuel-system	bore	stroke	compression-ratio	horsepower	peak-rpm	city-mpg	highway-mpg

c = [[3, 99,	50,	25,	20,	31,	2,	45,	11,	88.6,	168.8,	64.1,
      	48.8,2548, 0,2,	130,	0,	3.47,	2.68,
            	9,111,5000,21,	27]]
outcome = model.predict(c)
print('Car price is',outcome)
# Out:
# Car price is [10911.13012435]
