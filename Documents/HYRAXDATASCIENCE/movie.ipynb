# %%
#http://192.168.22.249/files/
import pandas as pd
data = pd.read_csv('data/movies.csv')
data.tail(50)
# Out:
#         Unnamed: 0  user_Id  item_id  rating  TimeStamp  \
# 99953        99953      405     1551       1  885546835
# 99954        99954      456     1551       3  881374193
# 99955        99955      747     1631       3  888638957
# 99956        99956      655     1631       4  888685734
# 99957        99957      495     1542       4  888637643
# 99958        99958      399     1542       2  882348592
# 99959        99959      405     1556       1  885549635
# 99960        99960      559     1556       3  891033759
# 99961        99961      863     1678       1  889289570
# 99962        99962      405     1567       1  885547123
# 99963        99963       60     1122       5  883326498
# 99964        99964       90     1201       5  891383687
# 99965        99965      405     1546       1  885549408
# 99966        99966      650     1627       3  891383786
# 99967        99967      851     1676       2  875731674
# 99968        99968      863     1680       2  889289570
# ...

# %%
#Step 1: Lets see which movie has highest rating on avg
data.groupby('title')['rating'].mean().sort_values(ascending=False)
# Out:
# title
# They Made Me a Criminal (1939)                  5.0
# Marlene Dietrich: Shadow and Light (1996)       5.0
# Saint of Fort Washington, The (1993)            5.0
# Someone Else's America (1995)                   5.0
# Star Kid (1997)                                 5.0
#                                                ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# King of New York (1990)                         1.0
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# Bloody Child, The (1996)                        1.0
# Crude Oasis, The (1995)                         1.0
# Name: rating, Length: 1664, dtype: float64

# %%
#Step 2 : How many people rated the movie
data.groupby('title')['rating'].count().sort_values(ascending=False)
# Out:
# title
# Star Wars (1977)                      584
# Contact (1997)                        509
# Fargo (1996)                          508
# Return of the Jedi (1983)             507
# Liar Liar (1997)                      485
#                                      ...
# Great Day in Harlem, A (1994)           1
# Other Voices, Other Rooms (1997)        1
# Good Morning (1971)                     1
# Girls Town (1996)                       1
# Á köldum klaka (Cold Fever) (1994)      1
# Name: rating, Length: 1664, dtype: int64

# %%
#Combine mean and count 
ratings = pd.DataFrame(data.groupby('title')['rating'].mean())
ratings['no_of_ratings'] = data.groupby('title')['rating'].count()
ratings.head(50)
# Out:
#                                                       rating  no_of_ratings
# title
# 'Til There Was You (1997)                           2.333333              9
# 1-900 (1994)                                        2.600000              5
# 101 Dalmatians (1996)                               2.908257            109
# 12 Angry Men (1957)                                 4.344000            125
# 187 (1997)                                          3.024390             41
# 2 Days in the Valley (1996)                         3.225806             93
# 20,000 Leagues Under the Sea (1954)                 3.500000             72
# 2001: A Space Odyssey (1968)                        3.969112            259
# 3 Ninjas: High Noon At Mega Mountain (1998)         1.000000              5
# 39 Steps, The (1935)                                4.050847             59
# 8 1/2 (1963)                                        3.815789             38
# ...

# %%
#Do pivot Table ,Pivot takes 3 variables
pivot = data.pivot_table(index='user_Id',columns='title',values='rating')
pivot
#Shows which users , what movie they rated ,what rating they gave
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_Id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_Id
# ...

# %%
#Pick a movie
movie = pivot['Liar Liar (1997)']

#Associate above and relate with others in the pivot
similar = pivot.corrwith(movie)
similar
#Put similar in a DataFrame
df = pd.DataFrame(similar,columns=['Correlations'])
df.sort_values('Correlations' ,ascending= False).head(20)

#At this point we can see the movie similar to Liar Liar
#Question how many people rated below movies
df = df.join(ratings['no_of_ratings'])
df[df['no_of_ratings']>100].sort_values('Correlations',
                                        ascending=False).head(20)
# Out:
# /home/user/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2846: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /home/user/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
#                                            Correlations  no_of_ratings
# title
# Liar Liar (1997)                               1.000000            485
# Batman Forever (1995)                          0.516968            114
# Mask, The (1994)                               0.484650            129
# Down Periscope (1996)                          0.472681            101
# Con Air (1997)                                 0.469828            137
# Pretty Woman (1990)                            0.469790            164
# 101 Dalmatians (1996)                          0.469765            109
# ...
